# %%
import pandas as pd
import numpy as np

# %%
mkt = pd.read_excel ('marketing_customer_analysis.xlsx')
mkt.shape # output is (number of rows, number of columns)
# mkt.head(5) # show first 5 rows
# Out:
# (10910, 26)

# %%
column_names = mkt.columns
column_names
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
column_names = mkt.columns
data_column = pd.DataFrame(columns=column_names)
data_column
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Customer, State, Customer Lifetime Value, Response, Coverage, Education, Effective To Date, EmploymentStatus, Gender, Income, Location Code, Marital Status, Monthly Premium Auto, Months Since Last Claim, Months Since Policy Inception, Number of Open Complaints, Number of Policies, Policy Type, Policy, Renew Offer Type, Sales Channel, Total Claim Amount, Vehicle Class, Vehicle Size, Vehicle Type]
# Index: []
#
# [0 rows x 26 columns]

# %%
mkt = mkt.rename(columns={"'EmploymentStatus": "Employment Status"})
mkt
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0             0.0  DK49336     Arizona              4809.216960       No
# 1             1.0  KX64629  California              2228.525238       No
# 2             2.0  LZ68649  Washington             14947.917300       No
# 3             3.0  XL78013      Oregon             22332.439460      Yes
# 4             4.0  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905     10905.0  FE99816      Nevada             15563.369440       No
# 10906     10906.0  KX53892      Oregon              5259.444853       No
# 10907     10907.0  TL39050     Arizona             23893.304100       No
# 10908     10908.0  WA60547  California             11971.977650       No
# 10909     10909.0  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
mkt_df = pd.DataFrame(mkt)
display(mkt_df)
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0             0.0  DK49336     Arizona              4809.216960       No
# 1             1.0  KX64629  California              2228.525238       No
# 2             2.0  LZ68649  Washington             14947.917300       No
# 3             3.0  XL78013      Oregon             22332.439460      Yes
# 4             4.0  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905     10905.0  FE99816      Nevada             15563.369440       No
# 10906     10906.0  KX53892      Oregon              5259.444853       No
# 10907     10907.0  TL39050     Arizona             23893.304100       No
# 10908     10908.0  WA60547  California             11971.977650       No
# 10909     10909.0  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
from pandas.api.types import is_numeric_dtype
is_numeric_dtype(mkt_df.columns)
# Out:
# False

# %%
column_datatypes = mkt_df.dtypes
column_datatypes
# Out:
# Unnamed: 0                              float64
# Customer                                 object
# State                                    object
# Customer Lifetime Value                 float64
# Response                                 object
# Coverage                                 object
# Education                                object
# Effective To Date                datetime64[ns]
# EmploymentStatus                         object
# Gender                                   object
# Income                                  float64
# Location Code                            object
# Marital Status                           object
# Monthly Premium Auto                    float64
# Months Since Last Claim                 float64
# Months Since Policy Inception           float64
# Number of Open Complaints               float64
# Number of Policies                      float64
# Policy Type                              object
# Policy                                   object
# ...

# %%
float64_columns = column_datatypes[column_datatypes == 'float64']
float64_columns
# Out:
# Unnamed: 0                       float64
# Customer Lifetime Value          float64
# Income                           float64
# Monthly Premium Auto             float64
# Months Since Last Claim          float64
# Months Since Policy Inception    float64
# Number of Open Complaints        float64
# Number of Policies               float64
# Total Claim Amount               float64
# dtype: object

# %%
float64_columns.index.to_list()
# Out:
# ['Unnamed: 0',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Months Since Last Claim',
#  'Months Since Policy Inception',
#  'Number of Open Complaints',
#  'Number of Policies',
#  'Total Claim Amount']

# %%
categorical_columns = column_datatypes[column_datatypes != 'float64']
categorical_columns.index.to_list()
# Out:
# ['Customer',
#  'State',
#  'Response',
#  'Coverage',
#  'Education',
#  'Effective To Date',
#  'EmploymentStatus',
#  'Gender',
#  'Location Code',
#  'Marital Status',
#  'Policy Type',
#  'Policy',
#  'Renew Offer Type',
#  'Sales Channel',
#  'Vehicle Class',
#  'Vehicle Size',
#  'Vehicle Type']

# %%
mkt_df.isnull().values.any()
mkt_df.dropna()
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 2             2.0  LZ68649  Washington             14947.917300       No
# 3             3.0  XL78013      Oregon             22332.439460      Yes
# 10           10.0  HG93801     Arizona              5154.764074       No
# 13           13.0  KR82385  California              5454.587929       No
# 16           16.0  FH51383  California              5326.677654       No
# ...           ...      ...         ...                      ...      ...
# 10902     10902.0  PP30874  California              3579.023825       No
# 10903     10903.0  SU71163     Arizona              2771.663013       No
# 10904     10904.0  QI63521      Nevada             19228.463620       No
# 10906     10906.0  KX53892      Oregon              5259.444853       No
# 10908     10908.0  WA60547  California             11971.977650       No
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# ...

# %%
datetime = mkt_df['Effective To Date']
datetime
# Out:
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 4       2011-01-17
#            ...
# 10905   2011-01-19
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# 10909   2011-01-08
# Name: Effective To Date, Length: 10910, dtype: datetime64[ns]

# %%
mkt_df['month'] = mkt_df['Effective To Date'].dt.month
mkt_df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0             0.0  DK49336     Arizona              4809.216960       No
# 1             1.0  KX64629  California              2228.525238       No
# 2             2.0  LZ68649  Washington             14947.917300       No
# 3             3.0  XL78013      Oregon             22332.439460      Yes
# 4             4.0  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905     10905.0  FE99816      Nevada             15563.369440       No
# 10906     10906.0  KX53892      Oregon              5259.444853       No
# 10907     10907.0  TL39050     Arizona             23893.304100       No
# 10908     10908.0  WA60547  California             11971.977650       No
# 10909     10909.0  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
firstqmkt_df = mkt_df[mkt_df['month'] == 1]
firstqmkt_df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 1             1.0  KX64629  California              2228.525238       No
# 3             3.0  XL78013      Oregon             22332.439460      Yes
# 4             4.0  QA50777      Oregon              9025.067525       No
# 8             8.0  FM55990  California              5989.773931      Yes
# 9             9.0  QX31376      Oregon             17114.328150       No
# ...           ...      ...         ...                      ...      ...
# 10902     10902.0  PP30874  California              3579.023825       No
# 10903     10903.0  SU71163     Arizona              2771.663013       No
# 10905     10905.0  FE99816      Nevada             15563.369440       No
# 10906     10906.0  KX53892      Oregon              5259.444853       No
# 10909     10909.0  IV32877         NaN              6857.519928      NaN
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# ...

# %%
secondqmkt_df = mkt_df[mkt_df['month'] == 2]
secondqmkt_df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0             0.0  DK49336     Arizona              4809.216960       No
# 2             2.0  LZ68649  Washington             14947.917300       No
# 5             5.0  HO81102         NaN              4745.181764      NaN
# 6             6.0  IW72280  California              5035.035257       No
# 7             7.0  IH64929  California              4956.247235       No
# ...           ...      ...         ...                      ...      ...
# 10899     10899.0  WU60905  California              8610.667489       No
# 10900     10900.0  VN73653      Oregon              6423.739052       No
# 10904     10904.0  QI63521      Nevada             19228.463620       No
# 10907     10907.0  TL39050     Arizona             23893.304100       No
# 10908     10908.0  WA60547  California             11971.977650       No
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# ...

# %%
thirdqmkt_df = mkt_df[mkt_df['month'] == 3]
thirdqmkt_df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Customer, State, Customer Lifetime Value, Response, Coverage, Education, Effective To Date, EmploymentStatus, Gender, Income, Location Code, Marital Status, Monthly Premium Auto, Months Since Last Claim, Months Since Policy Inception, Number of Open Complaints, Number of Policies, Policy Type, Policy, Renew Offer Type, Sales Channel, Total Claim Amount, Vehicle Class, Vehicle Size, Vehicle Type, month]
# Index: []
#
# [0 rows x 27 columns]
